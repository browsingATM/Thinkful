# %%
import os 
print(os.getcwd( ))
# Out:
# /Users/jakegrosek/Desktop/thinkful_python_files

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

df = pd.read_csv('suicide-albania.csv')
plt.plot(df['suicides/100k pop'])
plt.ylabel('suicides/100k pop')
plt.show()

# %%
#This graph is demonstrating the number of times

# %%
df = pd.read_csv('suicide-albania.csv')
plt.scatter(x=df['population'], y=df['suicides_no'])
plt.ylabel('# of suicides')
plt.xlabel('population')
plt.show()

# %%
#this graph shows the number

# %%
df = pd.read_csv('suicide-albania.csv')
plt.scatter(x=df['generation'], y=df['suicides_no'])
plt.ylabel('# of suicides')
plt.xlabel('generation')
plt.show()

# %%
#this graph shows the clustering of suicides in albania among the generations

# %%
df = pd.read_csv('suicide-albania.csv')
plt.hist(df['suicides_no'])
plt.xlabel('suicides/100k pop')
plt.show()
