# %%
import pandas as pd
from matplotlib import pyplot as plt
import numpy as np
from sklearn import linear_model
import xlrd
# %matplotlib inline
pd.options.display.float_format = '{:.3f}'.format

#suppress annoying hartmless errors
import warnings
warnings.filterwarnings(action="ignore", module="scipy", message="^internal gelsd")

# %%
loc = ("/Users/jakegrosek/Desktop/thinkful_py/Unit_2/nyc_crime.xls")
df = pd.read_csv("nyc_crime.csv")

# %%
df.columns = df.columns.str.strip().str.lower().str.replace(' ', '_').str.replace('(', '').str.replace(')', '')

# %%
df['population'] = pd.to_numeric(df['population'], errors='coerce')
df['violent crime'] = pd.to_numeric(df['violent_crime'], errors='coerce')
df['murder_and_nonnegligent_manslaughter'] = pd.to_numeric(df['murder_and_nonnegligent_manslaughter'], errors='coerce')
df['rape_revised_definition1'] = pd.to_numeric(df['rape_revised_definition1'], errors='coerce')
df['rape_legacy_definition2'] = pd.to_numeric(df['rape_legacy_definition2'], errors='coerce')
df['robbery'] = pd.to_numeric(df['robbery'], errors='coerce')
df['aggravated_assault'] = pd.to_numeric(df['aggravated_assault'], errors='coerce')
df['property_crime'] = pd.to_numeric(df['property_crime'], errors='coerce')
df['burglary'] = pd.to_numeric(df['burglary'], errors='coerce')
df['larceny-theft'] = pd.to_numeric(df['larceny-theft'], errors='coerce')
df['motor_vehicletheft'] = pd.to_numeric(df['motor_vehicle_theft'], errors='coerce')
df['arson3'] = pd.to_numeric(df['arson3'], errors='coerce')

# %%
# fills in NaN valeus with zero across the dataframe
df.fillna(0, inplace=True)

pop1 = df['population']
pop2 = df['population'].apply(lambda mike: mike ** 2)
murder = df['murder_and_nonnegligent_manslaughter']
robbery = df['robbery']

# %%
df.dtypes
# Out:
# city                                     object
# population                              float64
# violent_crime                            object
# murder_and_nonnegligent_manslaughter    float64
# rape_revised_definition1                float64
# rape_legacy_definition2                 float64
# robbery                                 float64
# aggravated_assault                      float64
# property_crime                          float64
# burglary                                float64
# larceny-theft                           float64
# motor_vehicle_theft                      object
# arson3                                  float64
# violent crime                           float64
# motor_vehicletheft                      float64
# dtype: object

# %%
regr = linear_model.LinearRegression()
y = df['property_crime']
x = df[['population','murder_and_nonnegligent_manslaughter','robbery']]
#are values in X the features?
regr.fit(x, y)

# Inspect the results.
print('\nCoefficients: \n', regr.coef_)
print('\nIntercept: \n', regr.intercept_)
print('\nR-squared:')
print(regr.score(x, y))
# Out:
# Coefficients:
#  [-0.19789472 -0.51786923 -0.02388776]
#
# Intercept:
#  172.201112378
#
# R-squared:
# 0.017806327822

# %% [markdown]
# Multicollinearity

# %%
correlation_matrix = df.corr()
display(correlation_matrix)
# Out:
#                                       population  \
# population                                 1.000
# murder_and_nonnegligent_manslaughter      -0.014
# rape_revised_definition1                     nan
# rape_legacy_definition2                   -0.042
# robbery                                   -0.037
# aggravated_assault                        -0.050
# property_crime                            -0.125
# burglary                                  -0.079
# larceny-theft                             -0.123
# arson3                                    -0.021
# violent crime                             -0.056
# motor_vehicletheft                        -0.036
#
#                                       murder_and_nonnegligent_manslaughter  \
# population                                                          -0.014
# murder_and_nonnegligent_manslaughter                                 1.000
# rape_revised_definition1                                               nan
# rape_legacy_definition2                                              0.178
# robbery                                                              0.127
# aggravated_assault                                                   0.052
# property_crime                                                      -0.044
# burglary                                                             0.008
# larceny-theft                                                       -0.043
# arson3                                                               0.129
# violent crime                                                        0.023
# motor_vehicletheft                                                   0.183
#
#                                       rape_revised_definition1  \
# population                                                 nan
# murder_and_nonnegligent_manslaughter                       nan
# rape_revised_definition1                                   nan
# rape_legacy_definition2                                    nan
# robbery                                                    nan
# aggravated_assault                                         nan
# property_crime                                             nan
# burglary                                                   nan
# larceny-theft                                              nan
# arson3                                                     nan
# violent crime                                              nan
# motor_vehicletheft                                         nan
#
#                                       rape_legacy_definition2  robbery  \
# population                                             -0.042   -0.037
# murder_and_nonnegligent_manslaughter                    0.178    0.127
# rape_revised_definition1                                  nan      nan
# rape_legacy_definition2                                 1.000    0.617
# robbery                                                 0.617    1.000
# aggravated_assault                                      0.443    0.619
# property_crime                                         -0.005   -0.008
# burglary                                                0.290    0.428
# larceny-theft                                           0.052    0.061
# arson3                                                  0.567    0.869
# violent crime                                           0.274    0.424
# motor_vehicletheft                                      0.960    0.637
#
#                                       aggravated_assault  property_crime  \
# population                                        -0.050          -0.125
# murder_and_nonnegligent_manslaughter               0.052          -0.044
# rape_revised_definition1                             nan             nan
# rape_legacy_definition2                            0.443          -0.005
# robbery                                            0.619          -0.008
# aggravated_assault                                 1.000           0.014
# property_crime                                     0.014           1.000
# burglary                                           0.730           0.137
# larceny-theft                                      0.134           0.776
# arson3                                             0.284          -0.038
# violent crime                                      0.712           0.097
# motor_vehicletheft                                 0.411          -0.035
#
#                                       burglary  larceny-theft  arson3  \
# population                              -0.079         -0.123  -0.021
# murder_and_nonnegligent_manslaughter     0.008         -0.043   0.129
# rape_revised_definition1                   nan            nan     nan
# rape_legacy_definition2                  0.290          0.052   0.567
# robbery                                  0.428          0.061   0.869
# aggravated_assault                       0.730          0.134   0.284
# property_crime                           0.137          0.776  -0.038
# burglary                                 1.000          0.272   0.082
# larceny-theft                            0.272          1.000  -0.025
# arson3                                   0.082         -0.025   1.000
# violent crime                            0.870          0.255   0.074
# motor_vehicletheft                       0.252          0.018   0.576
#
#                                       violent crime  motor_vehicletheft
# population                                   -0.056              -0.036
# murder_and_nonnegligent_manslaughter          0.023               0.183
# rape_revised_definition1                        nan                 nan
# rape_legacy_definition2                       0.274               0.960
# robbery                                       0.424               0.637
# aggravated_assault                            0.712               0.411
# property_crime                                0.097              -0.035
# burglary                                      0.870               0.252
# larceny-theft                                 0.255               0.018
# arson3                                        0.074               0.576
# violent crime                                 1.000               0.239
# motor_vehicletheft                            0.239               1.000

# %% [markdown]
# Multivariate Nonnormality

# %% [markdown]
# heteroscedasticity
